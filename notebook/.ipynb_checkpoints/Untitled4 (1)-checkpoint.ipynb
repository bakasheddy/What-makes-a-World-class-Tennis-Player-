# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\mapas\OneDrive\Desktop\wrangled_data.csv")
df=pd.DataFrame(df)
df
# Out:
#                       tourney_name surface tourney_level tourney_date  \
# 0                          Orlando    Clay             A   2000-05-01
# 1                          Orlando    Clay             A   2000-05-01
# 2                          Orlando    Clay             A   2000-05-01
# 3                          Orlando    Clay             A   2000-05-01
# 4                          Orlando    Clay             A   2000-05-01
# ...                            ...     ...           ...          ...
# 44305  Davis Cup WG R1: RUS vs SRB    Hard             D   2017-02-03
# 44306  Davis Cup WG R1: SUI vs USA    Hard             D   2017-02-03
# 44307  Davis Cup WG R1: SUI vs USA    Hard             D   2017-02-03
# 44308  Davis Cup WG R1: SUI vs USA    Hard             D   2017-02-03
# 44309  Davis Cup WG R1: SUI vs USA    Hard             D   2017-02-03
#
#        match_num          winner_name winner_hand  winner_ht winner_ioc  \
# 0            1.0        Antony Dupuis           R      185.0        FRA
# 1            2.0    Fernando Gonzalez           R      183.0        CHI
# 2            3.0  Paradorn Srichaphan           R      185.0        THA
# 3            4.0        Jan Siemerink           L      183.0        NED
# 4            5.0    Jason Stoltenberg           R      185.0        AUS
# ...          ...                  ...         ...        ...        ...
# 44305        2.0       Novak Djokovic           R      188.0        SRB
# 44306        1.0            Jack Sock           R      185.0        USA
# 44307        2.0           John Isner           R      206.0        USA
# 44308        4.0          Sam Querrey           R      198.0        USA
# 44309        5.0        Steve Johnson           R      188.0        USA
#
#        winner_age  ...  minutes  w_ace w_df  w_svpt w_1stIn  w_1stWon  \
# 0              27  ...    162.0    8.0  1.0   126.0    76.0      56.0
# 1              20  ...     86.0    4.0  2.0    67.0    35.0      25.0
# 2              21  ...     64.0    4.0  1.0    46.0    29.0      23.0
# 3              30  ...    150.0    8.0  6.0   109.0    56.0      43.0
# 4              30  ...     60.0    3.0  0.0    50.0    27.0      22.0
# ...           ...  ...      ...    ...  ...     ...     ...       ...
# 44305          30  ...    136.0    4.0  3.0   104.0    70.0      42.0
# 44306          24  ...    118.0   12.0  1.0    83.0    50.0      37.0
# 44307          32  ...    164.0   28.0  0.0   139.0    90.0      68.0
# 44308          29  ...     73.0   16.0  4.0    58.0    35.0      31.0
# 44309          27  ...     60.0    5.0  0.0    46.0    34.0      26.0
#
#        w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced
# 0          29.0     16.0       14.0       15.0
# 1          16.0     10.0        4.0        6.0
# 2          11.0      8.0        0.0        0.0
# 3          21.0     15.0        9.0       12.0
# 4          16.0      9.0        1.0        1.0
# ...         ...      ...        ...        ...
# 44305      16.0     14.0        9.0       14.0
# 44306      22.0     13.0        4.0        4.0
# 44307      25.0     19.0        8.0        9.0
# 44308      14.0     11.0        0.0        0.0
# 44309       9.0     10.0        3.0        4.0
#
# [44310 rows x 25 columns]

# %%
Roger_Federer=df[df['winner_name']=='Roger Federer']
Rafael_Nadal=df[df['winner_name']=='Rafael Nadal']
Novak_Djokovic=df[df['winner_name']=='Novak Djokovic']
David_Ferrer=df[df['winner_name']=='David Ferrer']
Andy_Murray=df[df['winner_name']=='Andy Murray']
Andy_Roddick=df[df['winner_name']=='Andy Roddick']
Tomas_Berdych=df[df['winner_name']=='Tomas Berdych']
Lleyton_Hewitt=df[df['winner_name']=='Lleyton Hewitt']
Tommy_Robredo=df[df['winner_name']=='Tommy Robredo']
Nikolay_Davydenko =df[df['winner_name']=='Nikolay Davydenko']
   
    

Roger_Federer=pd.DataFrame(Roger_Federer)
Rafael_Nadal=pd.DataFrame(Rafael_Nadal)
Novak_Djokovic=pd.DataFrame(Novak_Djokovic)
David_Ferrer=pd.DataFrame(David_Ferrer)
Andy_Murray=pd.DataFrame(Andy_Murray)
Andy_Roddick=pd.DataFrame(Andy_Roddick)
Tomas_Berdych=pd.DataFrame(Tomas_Berdych)
Lleyton_Hewitt=pd.DataFrame(Lleyton_Hewitt)
Tommy_Robredo=pd.DataFrame(Tommy_Robredo)
Nikolay_Davydenko=pd.DataFrame(Nikolay_Davydenko)

# %%
Wimbledon=df[df['tourney_name']=='Wimbledon']
Wimbledon=Wimbledon[['winner_name', 'tourney_name']].groupby('winner_name').count().sort_values('tourney_name', ascending=False)
Wimbledon.loc['Tommy Robredo']
Wimbledon.loc['Nikolay Davydenko']
Wimbledon_8=(Wimbledon.head(7)).append(Wimbledon.loc['David Ferrer'])
Wimbledon_9=Wimbledon_8.append(Wimbledon.loc['Tommy Robredo'])
Wimbledon_10=Wimbledon_9.append(Wimbledon.loc['Nikolay Davydenko'])
Wimbledon_10.columns=['Wimbledon']
Wimbledon_10.sort_values('winner_name', ascending=True)
# Out:
# C:\Users\mapas\AppData\Local\Temp\ipykernel_14160\3653948471.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Wimbledon_8=(Wimbledon.head(7)).append(Wimbledon.loc['David Ferrer'])
# C:\Users\mapas\AppData\Local\Temp\ipykernel_14160\3653948471.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Wimbledon_9=Wimbledon_8.append(Wimbledon.loc['Tommy Robredo'])
# C:\Users\mapas\AppData\Local\Temp\ipykernel_14160\3653948471.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Wimbledon_10=Wimbledon_9.append(Wimbledon.loc['Nikolay Davydenko'])
#                    Wimbledon
# winner_name
# Andy Murray               48
# Andy Roddick              41
# David Ferrer              26
# Lleyton Hewitt            39
# Nikolay Davydenko          7
# Novak Djokovic            47
# Rafael Nadal              39
# Roger Federer             78
# Tomas Berdych             34
# Tommy Robredo             14

# %%
Australian = top[top["tourney_name"] == 'Australian Open']
Roland = top[top['tourney_name'] == 'Roland Garros']
Wimbledon=top[top['tourney_name']=='Wimbledon']
Us = top[top['tourney_name'] == 'US Open']
oo = Australian, Roland, Wimbledon, Us.groupby('winner_name').count().sort_values('tourney_name', ascending=False)

# %%
US_Open=df[df['tourney_name']=='US Open']
US_Open=US_Open[['winner_name', 'tourney_name']].groupby('winner_name').count().sort_values('tourney_name', ascending=False)
US_Open7=US_Open.head(7)
US_Open8=US_Open7.append(US_Open.loc['Tomas Berdych'])
US_Open9=US_Open8.append(US_Open.loc['Nikolay Davydenko'])
US_Open10=US_Open9.append(US_Open.loc['David Ferrer'])
US_Open10.columns=['US Open']
US_Open10.sort_values('winner_name', ascending=True)
# Out:
# C:\Users\mapas\AppData\Local\Temp\ipykernel_14160\2671047788.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   US_Open8=US_Open7.append(US_Open.loc['Tomas Berdych'])
# C:\Users\mapas\AppData\Local\Temp\ipykernel_14160\2671047788.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   US_Open9=US_Open8.append(US_Open.loc['Nikolay Davydenko'])
# C:\Users\mapas\AppData\Local\Temp\ipykernel_14160\2671047788.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   US_Open10=US_Open9.append(US_Open.loc['David Ferrer'])
#                    US Open
# winner_name
# Andy Murray             37
# Andy Roddick            43
# David Ferrer            28
# Lleyton Hewitt          44
# Nikolay Davydenko       26
# Novak Djokovic          50
# Rafael Nadal            41
# Roger Federer           72
# Tomas Berdych           28
# Tommy Robredo           33

# %%
Top_tournament=[US_Open10, Wimbledon_10]
Tournament=pd.concat(Top_tournament, axis=1)

# %%
Tournament.plot.bar()
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')
