# %% [markdown]
# # Hamoye Premier Project.
#
# ## Group Catboost

# %% [markdown]
# ### Dataset Description
#
# > The Association of Tennis Professionals (ATP) is the governing body of the men's professional tennis circuits; this project uses a total of 17 datasets.In these datasets there are individual csv files for ATP tournament from 2000 to 2017.
# The numbers in the last columns are absolute values, using them you can calculate percentages.
#
# the following is the naming abbrevations of the column names used in the data.
#
# ace = absolute number of aces
#
# df = number of double faults
#
# svpt = total serve points
#
# 1stin = 1st serve in
#
# 1st won = points won on 1st serve
#
# 2ndwon = points won on 2nd serve
#
# SvGms = serve games
#
# bpSaved = break point saved
#
# bpFaced = break point faced

# %% [markdown]
# ### Question(s) For Analysis
#
# >- Who is the greatest Tennis player of all time?
# >- What makes a great Tennis player?

# %%
import numpy as np
import pandas as pd
from scipy import stats
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %matplotlib inline

# %%
#Loading datasets from folder called 'datasets' and merging all csv data
folder_name = '../datasets'
files = glob.glob(os.path.join(folder_name, "*.csv"))
df = pd.concat((pd.read_csv(f, low_memory=False) for f in files), ignore_index = True)

# %% [markdown]
# ### Preliminary Wrangling

# %%
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2000-717      Orlando    Clay       32.0             A    20000501.0
# 1   2000-717      Orlando    Clay       32.0             A    20000501.0
# 2   2000-717      Orlando    Clay       32.0             A    20000501.0
# 3   2000-717      Orlando    Clay       32.0             A    20000501.0
# 4   2000-717      Orlando    Clay       32.0             A    20000501.0
#
#    match_num  winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df  \
# 0        1.0   102179.0          NaN          NaN  ...      15.0  13.0   4.0
# 1        2.0   103602.0          NaN            Q  ...       6.0   0.0   0.0
# 2        3.0   103387.0          NaN          NaN  ...       0.0   2.0   2.0
# 3        4.0   101733.0          NaN          NaN  ...      12.0   4.0   6.0
# 4        5.0   101727.0          4.0          NaN  ...       1.0   0.0   3.0
#
#   l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved l_bpFaced
# 0  110.0     59.0      49.0      31.0     17.0        4.0       4.0
# 1   57.0     24.0      13.0      17.0     10.0        4.0       9.0
# 2   65.0     39.0      22.0      10.0      8.0        6.0      10.0
# 3  104.0     57.0      35.0      24.0     15.0        6.0      11.0
# 4   47.0     28.0      17.0      10.0      8.0        3.0       6.0
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (53571, 49)

# %%
df.describe()
# Out:
#           draw_size  tourney_date     match_num      winner_id   winner_seed  \
# count  53508.000000  5.350800e+04  53508.000000   53508.000000  22305.000000
# mean      53.244431  2.007903e+07     38.743029  104044.714005      7.262990
# std       38.951310  4.938173e+04     59.206285    2338.649843      6.669687
# min        4.000000  2.000010e+07      1.000000  100644.000000      1.000000
# 25%       32.000000  2.004012e+07      8.000000  103252.000000      3.000000
# 50%       32.000000  2.008030e+07     20.000000  103909.000000      5.000000
# 75%       64.000000  2.012062e+07     39.000000  104676.000000      9.000000
# max      128.000000  2.017020e+07    319.000000  202382.000000     35.000000
#
#           winner_ht    winner_age   winner_rank  winner_rank_points  \
# count  50001.000000  53490.000000  52432.000000        52432.000000
# mean     185.624308     26.030216     82.360047         1523.461913
# std        6.793573      3.657063    146.217219         1998.389560
# min      163.000000     15.715264      1.000000            1.000000
# 25%      180.000000     23.362081     17.000000          535.000000
# 50%      185.000000     25.937029     44.000000          893.000000
# 75%      190.000000     28.560575     86.000000         1615.000000
# max      208.000000     39.627652   2101.000000        16950.000000
#
#             loser_id  ...     w_bpFaced         l_ace          l_df  \
# count   53508.000000  ...  47740.000000  47740.000000  47740.000000
# mean   104182.875458  ...      5.040008      4.997947      3.384311
# std      3324.481911  ...      4.035421      4.773229      2.529890
# min    100644.000000  ...      0.000000      0.000000      0.000000
# 25%    103171.000000  ...      2.000000      2.000000      2.000000
# 50%    103908.000000  ...      4.000000      4.000000      3.000000
# 75%    104678.000000  ...      7.000000      7.000000      5.000000
# max    202359.000000  ...     30.000000    103.000000     23.000000
#
#              l_svpt       l_1stIn      l_1stWon      l_2ndWon       l_SvGms  \
# count  47740.000000  47740.000000  47740.000000  47740.000000  47740.000000
# mean      80.471093     47.857750     31.845140     14.994009     12.218789
# std       29.170992     19.135274     14.292082      7.277628      4.220815
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       59.000000     34.000000     22.000000     10.000000      9.000000
# 50%       75.000000     45.000000     30.000000     14.000000     11.000000
# 75%       96.000000     58.000000     40.000000     19.000000     15.000000
# max      489.000000    328.000000    284.000000    101.000000     91.000000
#
#           l_bpSaved     l_bpFaced
# count  47740.000000  47740.000000
# mean       4.767176      8.646732
# std        3.259114      4.128620
# min        0.000000      0.000000
# 25%        2.000000      6.000000
# 50%        4.000000      8.000000
# 75%        7.000000     11.000000
# max       25.000000     34.000000
#
# [8 rows x 35 columns]

# %% [markdown]
# ## Quality Issues
#
# - Bad date format/datatype
# - Bad data types for winner_age, winner_rank, and winner_rank_points columns
# - null values present

# %%
# changing tourney_date format and datatype
df['tourney_date'] = df['tourney_date'].astype(str).apply(lambda x: pd.to_datetime(x, format='%Y%m%d', errors= 'coerce'))

# %%
#displays enire column of the dataframe
pd.set_option('display.max.column', None)

# %%
df.sample(15)
# Out:
#       tourney_id                 tourney_name surface  draw_size  \
# 1977    2000-416                 Rome Masters    Clay       64.0
# 4531    2001-891                      Chennai    Hard       32.0
# 6829     2002-73                     Tashkent    Hard       32.0
# 39295   2012-339                     Brisbane    Hard       32.0
# 17757   2005-316                       Bastad    Clay       32.0
# 35216  2010-D060  Davis Cup G2 PO: MAS vs POC    Hard        4.0
# 22028   2006-568               St. Petersburg  Carpet       32.0
# 41840   2013-540                    Wimbledon   Grass      128.0
# 40524   2012-580              Australian Open    Hard      128.0
# 24208   2007-423                  Los Angeles    Hard       32.0
# 46079   2014-308                       Munich    Clay       28.0
# 26636   2008-306                  Poertschach    Clay       32.0
# 33796   2010-747                      Beijing    Hard       32.0
# 34108   2010-520                Roland Garros    Clay      128.0
# 13427   2004-425                    Barcelona    Clay       56.0
#
#       tourney_level tourney_date  match_num  winner_id  winner_seed  \
# 1977              M   2000-05-08       63.0   102796.0          3.0
# 4531              A   2001-01-01       14.0   102911.0          NaN
# 6829              A   2002-09-09       11.0   102694.0          NaN
# 39295             A   2012-01-01       15.0   105902.0          NaN
# 17757             A   2005-07-04       28.0   103181.0          NaN
# 35216             D   2010-07-09        2.0   104702.0          NaN
# 22028             A   2006-10-23       21.0   103018.0          NaN
# 41840             G   2013-06-24       18.0   105138.0          NaN
# 40524             G   2012-01-16       46.0   104122.0          NaN
# 24208             A   2007-07-16       13.0   104098.0          5.0
# 46079             A   2014-04-28        3.0   105064.0          NaN
# 26636             A   2008-05-18       18.0   104312.0          6.0
# 33796             A   2010-10-04       18.0   104468.0          NaN
# 34108             G   2010-05-24       71.0   103656.0         29.0
# 13427             A   2004-04-26       12.0   103535.0          NaN
#
#       winner_entry            winner_name winner_hand  winner_ht winner_ioc  \
# 1977           NaN          Magnus Norman           R      188.0        SWE
# 4531           NaN       Andrei Stoliarov           R      178.0        RUS
# 6829           NaN       Lars Burgsmuller           R      183.0        GER
# 39295           WC        James Duckworth           R      183.0        AUS
# 17757          NaN             Jiri Vanek           R      185.0        CZE
# 35216          NaN          Michael Leong           U        NaN        SOL
# 22028          NaN             Max Mirnyi           R      196.0        BLR
# 41840          NaN  Roberto Bautista Agut           R        NaN        ESP
# 40524          NaN         Carlos Berlocq           R      183.0        ARG
# 24208          NaN        Dmitry Tursunov           R      185.0        RUS
# 46079            Q        Thomaz Bellucci           L      188.0        BRA
# 26636          NaN          Andreas Seppi           R      190.0        ITA
# 33796          NaN           Gilles Simon           R      183.0        FRA
# 34108          NaN        Albert Montanes           R      175.0        ESP
# 13427            Q       Olivier Patience           R      180.0        FRA
#
#        winner_age  winner_rank  winner_rank_points  loser_id  loser_seed  \
# 1977    23.939767          4.0              2314.0  102856.0         4.0
# 4531    23.978097          NaN                 NaN  102405.0         NaN
# 6829    26.759754         79.0               493.0  103715.0         NaN
# 39295   19.947981        275.0               171.0  103917.0         NaN
# 17757   27.195072        105.0               402.0  103169.0         NaN
# 35216   24.298426       1274.0                 3.0  108961.0         NaN
# 22028   29.297741         60.0               645.0  102318.0         NaN
# 41840   25.193703         60.0               778.0  104559.0         NaN
# 40524   28.950034         61.0               801.0  104619.0         NaN
# 24208   24.591376         27.0              1080.0  103821.0         NaN
# 46079   26.327173        122.0               467.0  104471.0         8.0
# 26636   24.240931         32.0               973.0  104534.0         NaN
# 33796   25.768652         43.0              1055.0  103582.0         NaN
# 34108   29.489391         34.0              1325.0  104735.0         NaN
# 13427   24.087611        113.0               361.0  102106.0         NaN
#
#       loser_entry               loser_name loser_hand  loser_ht loser_ioc  \
# 1977          NaN          Gustavo Kuerten          R     190.0       BRA
# 4531           WC          Mahesh Bhupathi          R     185.0       IND
# 6829            Q  Kirill Ivanov Smolensky          R       NaN       RUS
# 39295         NaN            Nicolas Mahut          R     190.0       FRA
# 17757         NaN          Oscar Hernandez          R     180.0       ESP
# 35216         NaN  Abd Hazli Bin Zainuddin          U       NaN       MAS
# 22028         NaN             Andrei Pavel          R     183.0       ROU
# 41840           Q      Teymuraz Gabashvili          R     188.0       RUS
# 40524           Q        Jesse Huta Galung          R     188.0       NED
# 24208         NaN          Danai Udomchoke          R     173.0       THA
# 46079         NaN               Ivan Dodig          R     183.0       CRO
# 26636         NaN                Dudi Sela          R     175.0       ISR
# 33796           Q           Michael Berrer          L     193.0       GER
# 34108           Q             Tobias Kamke          R     180.0       GER
# 13427         NaN       Davide Sanguinetti          R     188.0       ITA
#
#        loser_age  loser_rank  loser_rank_points               score  best_of  \
# 1977   23.657769         6.0             2012.0     6-3 4-6 6-4 6-4      5.0
# 4531   26.570842         NaN                NaN      3-6 6-2 7-6(2)      3.0
# 6829   21.552361       544.0               35.0         4-6 6-0 6-2      3.0
# 39295  29.946612        80.0              653.0             6-4 6-4      3.0
# 17757  27.233402        80.0              488.0             6-4 6-2      3.0
# 35216  29.664613         NaN                NaN         6-1 6-0 6-1      5.0
# 22028  32.736482       106.0              393.0             6-3 7-5      3.0
# 41840  28.087611       137.0              404.0      6-3 6-4 7-6(3)      5.0
# 40524  26.277892       233.0              205.0  2-6 6-3 7-6(3) 6-3      5.0
# 24208  25.927447       104.0              406.0             6-1 6-4      3.0
# 46079  29.316906        36.0             1135.0          7-6(0) 6-4      3.0
# 26636  23.123888        61.0              584.0             7-5 6-1      3.0
# 33796  30.258727        51.0              917.0   6-7(6) 6-4 7-6(4)      3.0
# 34108  24.008214       157.0              307.0         6-3 6-2 6-1      5.0
# 13427  31.668720       115.0              358.0      6-7(1) 6-4 6-3      3.0
#
#       round  minutes  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  \
# 1977      F    185.0   14.0   1.0   121.0     81.0      57.0      21.0
# 4531    R32    120.0    3.0   5.0    97.0     41.0      29.0      31.0
# 6829    R32    112.0   11.0   2.0    83.0     50.0      37.0      16.0
# 39295   R32     71.0    5.0   1.0    52.0     31.0      25.0      12.0
# 17757    QF    100.0    5.0   2.0    59.0     33.0      26.0      15.0
# 35216    RR      NaN    NaN   NaN     NaN      NaN       NaN       NaN
# 22028   R16     86.0   16.0   2.0    58.0     38.0      30.0      15.0
# 41840  R128    149.0    6.0   1.0   117.0     88.0      63.0      16.0
# 40524  R128    206.0    9.0   3.0   127.0     85.0      63.0      15.0
# 24208   R32     62.0    8.0   3.0    48.0     22.0      20.0      15.0
# 46079   R32    102.0    2.0   3.0    77.0     43.0      34.0      18.0
# 26636   R16     75.0    4.0   1.0    66.0     41.0      30.0      14.0
# 33796   R16    186.0   16.0   5.0   117.0     74.0      58.0      19.0
# 34108   R64    105.0    2.0   4.0    84.0     50.0      41.0      16.0
# 13427   R64    125.0    6.0   4.0   102.0     61.0      38.0      25.0
#
#        w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  \
# 1977      20.0        5.0        9.0   15.0   5.0   142.0     68.0      48.0
# 4531      14.0        5.0        8.0   18.0   3.0   120.0     67.0      45.0
# 6829      12.0        5.0        7.0    9.0   5.0    99.0     61.0      33.0
# 39295     10.0        1.0        3.0    5.0   5.0    52.0     32.0      21.0
# 17757      9.0        4.0        4.0    0.0   3.0    75.0     47.0      33.0
# 35216      NaN        NaN        NaN    NaN   NaN     NaN      NaN       NaN
# 22028     11.0        0.0        0.0    2.0   2.0    73.0     52.0      33.0
# 41840     16.0        6.0        8.0    5.0   5.0   106.0     62.0      40.0
# 40524     20.0        8.0       13.0    8.0  12.0   122.0     64.0      50.0
# 24208      9.0        0.0        1.0    1.0   3.0    64.0     31.0      16.0
# 46079     11.0        5.0        6.0    4.0   3.0    70.0     32.0      24.0
# 26636      9.0        9.0        9.0    2.0   0.0    63.0     43.0      24.0
# 33796     17.0        6.0        7.0    5.0   2.0   138.0     96.0      67.0
# 34108     12.0        8.0        8.0    1.0   4.0    72.0     46.0      25.0
# 13427     15.0        4.0        7.0    2.0   2.0   108.0     63.0      38.0
#
#        l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced
# 1977       34.0     19.0       15.0       21.0
# 4531       23.0     15.0        9.0       13.0
# 6829       17.0     12.0       12.0       18.0
# 39295       9.0     10.0        3.0        7.0
# 17757       9.0      9.0        4.0        7.0
# 35216       NaN      NaN        NaN        NaN
# 22028      11.0     10.0        3.0        5.0
# 41840      21.0     15.0        6.0       10.0
# 40524      23.0     18.0        7.0       12.0
# 24208      17.0      8.0        3.0        7.0
# 46079      18.0     11.0        1.0        3.0
# 26636      10.0     10.0        4.0        8.0
# 33796      16.0     17.0        5.0        7.0
# 34108       9.0     12.0        6.0       12.0
# 13427      24.0     16.0        9.0       15.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53571 entries, 0 to 53570
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          53508 non-null  object
#  1   tourney_name        53508 non-null  object
#  2   surface             53390 non-null  object
#  3   draw_size           53508 non-null  float64
#  4   tourney_level       53508 non-null  object
#  5   tourney_date        53508 non-null  datetime64[ns]
#  6   match_num           53508 non-null  float64
#  7   winner_id           53508 non-null  float64
#  8   winner_seed         22305 non-null  float64
#  9   winner_entry        6210 non-null   object
#  10  winner_name         53508 non-null  object
#  11  winner_hand         53494 non-null  object
#  12  winner_ht           50001 non-null  float64
#  13  winner_ioc          53508 non-null  object
#  14  winner_age          53490 non-null  float64
#  15  winner_rank         52432 non-null  float64
#  16  winner_rank_points  52432 non-null  float64
#  17  loser_id            53508 non-null  float64
#  18  loser_seed          11964 non-null  float64
#  19  loser_entry         10427 non-null  object
#  20  loser_name          53508 non-null  object
#  21  loser_hand          53479 non-null  object
#  22  loser_ht            47795 non-null  float64
#  23  loser_ioc           53508 non-null  object
#  24  loser_age           53478 non-null  float64
#  25  loser_rank          51716 non-null  float64
#  26  loser_rank_points   51716 non-null  float64
#  27  score               53507 non-null  object
#  28  best_of             53508 non-null  float64
#  29  round               53508 non-null  object
#  30  minutes             46506 non-null  float64
#  31  w_ace               47740 non-null  float64
#  32  w_df                47740 non-null  float64
#  33  w_svpt              47740 non-null  float64
#  34  w_1stIn             47740 non-null  float64
#  35  w_1stWon            47740 non-null  float64
#  36  w_2ndWon            47740 non-null  float64
#  37  w_SvGms             47740 non-null  float64
#  38  w_bpSaved           47740 non-null  float64
#  39  w_bpFaced           47740 non-null  float64
#  40  l_ace               47740 non-null  float64
#  41  l_df                47740 non-null  float64
#  42  l_svpt              47740 non-null  float64
#  43  l_1stIn             47740 non-null  float64
#  44  l_1stWon            47740 non-null  float64
#  45  l_2ndWon            47740 non-null  float64
#  46  l_SvGms             47740 non-null  float64
#  47  l_bpSaved           47740 non-null  float64
#  48  l_bpFaced           47740 non-null  float64
# dtypes: datetime64[ns](1), float64(34), object(14)
# memory usage: 20.0+ MB

# %%
# dropping unnecessary columns we won't be needing for this project
columns = ['tourney_name', 'surface', 'tourney_level', 'tourney_date', 'match_num', 'winner_name', 'winner_hand',
           'winner_ht', 'winner_ioc', 'round', 'winner_age', 'winner_rank', 'winner_rank_points', 'score',
           'best_of', 'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon', 'w_SvGms',
           'w_bpSaved', 'w_bpFaced']
for i in df.columns:
    if i in columns:
        pass
    else:
        df.drop(i, axis=1, inplace = True)

# %%
df.sample(10)
# Out:
#                       tourney_name surface tourney_level tourney_date  \
# 11934                  Long Island    Hard             A   2003-08-18
# 4006                       Atlanta    Clay             A   2001-04-23
# 48740              Australian Open    Hard             G   2015-01-19
# 23848                 Rome Masters    Clay             M   2007-05-07
# 44021  Davis Cup WG R1: USA vs BRA    Hard             D   2013-02-01
# 14403               St. Petersburg  Carpet             A   2004-10-25
# 11192                        Sopot    Clay             A   2003-07-28
# 25709                   Dusseldorf    Clay             A   2007-05-20
# 2113                    Washington    Hard             A   2000-08-14
# 25106              Australian Open    Hard             G   2007-01-15
#
#        match_num        winner_name winner_hand  winner_ht winner_ioc  \
# 11934        8.0     Flavio Saretta           R      183.0        BRA
# 4006        29.0     Xavier Malisse           R      185.0        BEL
# 48740       90.0         Joao Sousa           R        NaN        POR
# 23848       36.0  Nikolay Davydenko           R      178.0        RUS
# 44021        3.0    Thomaz Bellucci           L      188.0        BRA
# 14403       10.0   Julien Benneteau           R      185.0        FRA
# 11192        8.0      Olivier Mutis           R      175.0        FRA
# 25709        6.0      Tomas Berdych           R      196.0        CZE
# 2113        10.0    Andrea Gaudenzi           R      183.0        ITA
# 25106      109.0        James Blake           R      185.0        USA
#
#        winner_age  winner_rank  winner_rank_points                   score  \
# 11934   23.137577         48.0               738.0                 3-0 RET
# 4006    20.761123         78.0               503.0          7-6(1) 3-6 6-3
# 48740   25.806982         55.0               822.0  4-6 7-6(4) 6-4 1-0 RET
# 23848   25.927447          4.0              2805.0              7-6(4) 7-5
# 44021   25.081451         36.0              1077.0  2-6 6-4 6-7(7) 6-4 6-3
# 14403   22.847365         71.0               538.0             6-4 1-6 6-4
# 11192   25.481177         71.0               572.0                 6-2 6-4
# 25709   21.672827         12.0              2020.0                 6-3 6-2
# 2113    27.041752        108.0               372.0                 6-4 6-4
# 25106   27.049966          5.0              2530.0          7-6(7) 7-5 6-2
#
#        best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  \
# 11934      3.0   R32      9.0    2.0   0.0     9.0      6.0       5.0
# 4006       3.0    SF    127.0    5.0   1.0    94.0     57.0      44.0
# 48740      5.0   R64    151.0    8.0   1.0    98.0     68.0      49.0
# 23848      3.0   R32    137.0    2.0   4.0    86.0     58.0      39.0
# 44021      5.0    RR      NaN    NaN   NaN     NaN      NaN       NaN
# 14403      3.0   R32    117.0   13.0   3.0    89.0     58.0      34.0
# 11192      3.0   R32     56.0    0.0   0.0    44.0     19.0      15.0
# 25709      3.0    RR     72.0    3.0   0.0    53.0     26.0      18.0
# 2113       3.0   R64     79.0    3.0   1.0    57.0     33.0      24.0
# 25106      5.0   R32    113.0   10.0   3.0    87.0     55.0      44.0
#
#        w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced
# 11934       3.0      2.0        0.0        0.0
# 4006       18.0     15.0        7.0       10.0
# 48740      16.0     16.0        7.0       10.0
# 23848      13.0     12.0        8.0       11.0
# 44021       NaN      NaN        NaN        NaN
# 14403      17.0     13.0        7.0       12.0
# 11192      21.0      9.0        0.0        0.0
# 25709      18.0      8.0        2.0        2.0
# 2113       13.0     10.0        4.0        6.0
# 25106      21.0     16.0        1.0        4.0

# %%
# rounding values of the defined columns to it's whole numbers
cols = ['winner_age', 'winner_ht', 'winner_rank', 'winner_rank_points']
df[cols] = df[cols].apply(np.round)

# %%
df.isna().sum()
# Out:
# tourney_name            63
# surface                181
# tourney_level           63
# tourney_date            63
# match_num               63
# winner_name             63
# winner_hand             77
# winner_ht             3570
# winner_ioc              63
# winner_age              81
# winner_rank           1139
# winner_rank_points    1139
# score                   64
# best_of                 63
# round                   63
# minutes               7065
# w_ace                 5831
# w_df                  5831
# w_svpt                5831
# w_1stIn               5831
# w_1stWon              5831
# w_2ndWon              5831
# w_SvGms               5831
# w_bpSaved             5831
# w_bpFaced             5831
# dtype: int64

# %%
#dropping nulls
df.dropna(inplace=True)

# %%
#converting cols datatype to int
df[cols] = df[cols].astype(int)

# %%
#checking if null values still exist in the dataframe
assert df.all().isna().sum() == 0

# %%
# changing winner hand to category since it's just two observations; L and R
df['winner_hand'] = df['winner_hand'].astype('category')

# %%
df['winner_hand'].dtype
# Out:
# CategoricalDtype(categories=['L', 'R'], ordered=False)

# %%
df.describe()
# Out:
#           match_num     winner_ht    winner_age   winner_rank  \
# count  44310.000000  44310.000000  44310.000000  44310.000000
# mean      40.813699    185.651704     26.219567     56.963123
# std       56.857096      6.750664      3.586402     68.830520
# min        1.000000    163.000000     16.000000      1.000000
# 25%       12.000000    180.000000     24.000000     16.000000
# 50%       23.000000    185.000000     26.000000     40.000000
# 75%       43.000000    190.000000     29.000000     76.000000
# max      319.000000    208.000000     38.000000   1554.000000
#
#        winner_rank_points       best_of       minutes         w_ace  \
# count        44310.000000  44310.000000  44310.000000  44310.000000
# mean          1612.563236      3.382126    104.451659      6.803679
# std           2020.629593      0.786286     40.308286      5.435062
# min              1.000000      3.000000      3.000000      0.000000
# 25%            590.000000      3.000000     75.000000      3.000000
# 50%            945.000000      3.000000     97.000000      6.000000
# 75%           1705.000000      3.000000    126.000000      9.000000
# max          16950.000000      5.000000   1146.000000    113.000000
#
#                w_df        w_svpt       w_1stIn      w_1stWon      w_2ndWon  \
# count  44310.000000  44310.000000  44310.000000  44310.000000  44310.000000
# mean       2.626269     77.383299     47.225818     35.706048     16.731234
# std        2.272073     29.160107     18.792436     13.445849      7.070905
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000     56.000000     34.000000     26.000000     12.000000
# 50%        2.000000     72.000000     44.000000     33.000000     16.000000
# 75%        4.000000     94.000000     57.000000     43.000000     21.000000
# max       23.000000    491.000000    361.000000    292.000000     82.000000
#
#             w_SvGms     w_bpSaved     w_bpFaced
# count  44310.000000  44310.000000  44310.000000
# mean      12.405213      3.461341      5.039517
# std        4.210821      3.079335      4.034746
# min        0.000000      0.000000      0.000000
# 25%        9.000000      1.000000      2.000000
# 50%       11.000000      3.000000      4.000000
# 75%       15.000000      5.000000      7.000000
# max       90.000000     24.000000     29.000000

# %%
df.sample(10)
# Out:
#          tourney_name surface tourney_level tourney_date  match_num  \
# 45252         Estoril    Clay             A   2014-04-28       22.0
# 15744       Wimbledon   Grass             G   2004-06-21      114.0
# 4224        Amsterdam    Clay             A   2001-07-16       21.0
# 6794     Indianapolis    Hard             A   2002-08-12       31.0
# 42585   Miami Masters    Hard             M   2013-03-20       58.0
# 35535          Gstaad    Clay             A   2011-07-25       14.0
# 28215      Casablanca    Clay             A   2008-05-18        9.0
# 22958  St. Petersburg  Carpet             A   2007-10-22       16.0
# 30068         Memphis    Hard             A   2009-02-16       22.0
# 46605      Washington    Hard             A   2014-07-28       27.0
#
#              winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 45252     Victor Hanescu           R        198        ROU          33
# 15744     Lleyton Hewitt           R        180        AUS          23
# 4224      Olivier Rochus           R        168        BEL          20
# 6794      Nicolas Kiefer           R        183        GER          25
# 42585    Jarkko Nieminen           L        185        FIN          32
# 35535    Feliciano Lopez           L        188        ESP          30
# 28215  Younes El Aynaoui           R        193        MAR          37
# 22958        Andy Murray           R        190        GBR          20
# 30068          Dudi Sela           R        175        ISR          24
# 46605      Denis Istomin           R        188        UZB          28
#
#        winner_rank  winner_rank_points               score  best_of round  \
# 45252           93                 601             6-1 7-5      3.0    QF
# 15744           10                1745  6-4 6-2 4-6 7-6(3)      5.0   R16
# 4224            84                 525             6-4 6-0      3.0   R16
# 6794            65                 610             6-4 7-5      3.0   R32
# 42585           49                 825             6-2 6-2      3.0   R64
# 35535           24                1390             6-3 6-4      3.0   R16
# 28215          189                 214      6-2 6-7(6) 6-3      3.0   R32
# 22958           16                1480             6-2 6-2      3.0   R32
# 30068           86                 953       7-6(4) 7-6(4)      3.0   R16
# 46605           41                1040          6-4 7-6(6)      3.0   R32
#
#        minutes  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  \
# 45252     82.0    2.0   0.0    65.0     44.0      30.0      10.0     10.0
# 15744    165.0    4.0   7.0   133.0     72.0      59.0      30.0     20.0
# 4224      56.0    3.0   3.0    40.0     20.0      17.0      12.0      8.0
# 6794      97.0    7.0   4.0    61.0     31.0      27.0      16.0     11.0
# 42585     76.0    3.0   0.0    63.0     33.0      23.0      17.0      8.0
# 35535     73.0    7.0   3.0    62.0     41.0      32.0       9.0     10.0
# 28215    130.0   12.0   8.0   109.0     71.0      53.0      19.0     15.0
# 22958     52.0    3.0   0.0    39.0     21.0      18.0      14.0      8.0
# 30068    103.0    4.0   3.0    92.0     54.0      36.0      21.0     12.0
# 46605     89.0    4.0   2.0    71.0     49.0      34.0      12.0     11.0
#
#        w_bpSaved  w_bpFaced
# 45252        3.0        5.0
# 15744        8.0       11.0
# 4224         0.0        1.0
# 6794         1.0        2.0
# 42585        8.0        9.0
# 35535        1.0        2.0
# 28215       10.0       11.0
# 22958        0.0        0.0
# 30068        5.0        8.0
# 46605        5.0        7.0

# %%
df.to_csv('wrangled_data.csv', index=False)

# %% [markdown]
# - Hands of the top 10 players.
# - Heights  of the top ten players.
# - Analysis on rank points
# - The top 10 players country of origin.

# %% [markdown]
# ## Univariate analysis

# %%
rcParams['figure.figsize'] = 10, 7

base_color = sns.color_palette()[0]
sns.countplot(data=df, x=df['tourney_date'].dt.to_period('Y'), color=base_color)
plt.title('Tournaments per year', fontsize=20, y=1.015)
plt.xlabel('years', labelpad=10, fontsize=16)
plt.ylabel('count [tourney]', labelpad=10, fontsize=16)
# Out:
# Text(0, 0.5, 'count [tourney]')

# %%
rcParams['figure.figsize'] = 10, 7
events = (df['tourney_date'].dt.to_period('Y').value_counts().sort_index())/df.shape[0]
base_color = sns.color_palette()[0]
sns.pointplot(x=events.index, y= events.values, color=base_color)
plt.title('Tournaments per year', fontsize=20, y=1.015)
plt.xlabel('years', labelpad=10, fontsize=16)
plt.ylabel('count [tourney]', labelpad=10, fontsize=16)
# Out:
# Text(0, 0.5, 'count [tourney]')

# %%
# Payer with most win
DF=df.groupby('winner_name')['winner_name'].count().sort_values(ascending= False)
Df=DF.head(10)
Df=pd.DataFrame(Df)
Df
# Out:
#                    winner_name
# winner_name
# Roger Federer              984
# Rafael Nadal               759
# Novak Djokovic             689
# David Ferrer               650
# Andy Murray                581
# Andy Roddick               575
# Tomas Berdych              531
# Lleyton Hewitt             511
# Tommy Robredo              495
# Nikolay Davydenko          459

# %%
rcParams['figure.figsize'] = 10,8

plt.bar(x=Df.index, height=Df['winner_name']);
plt.xticks(rotation = 90)
plt.xlabel('Names')
plt.ylabel('Number of wins')
plt.title( 'Total number of wins of top ten winners from 2000 to 2017')
# Out:
# Text(0.5, 1.0, 'Total number of wins of top ten winners from 2000 to 2017')

# %%
li = ('Roger Federer', 'Rafael Nadal', 'Novak Djokovic', 'David Ferrer', 'Andy Murray', 
      'Andy Roddick', 'Tomas Berdych', 'Lleyton Hewitt', 'Tommy Robredo', 'Nikolay Davydenko')
top = df[df['winner_name'].isin(li)]

# %%
top.sample(10)
# Out:
#               tourney_name surface tourney_level tourney_date  match_num  \
# 45766         Delray Beach    Hard             A   2014-02-17        8.0
# 17207            Stuttgart    Clay             A   2005-07-18       40.0
# 41895            Wimbledon   Grass             G   2013-06-24       73.0
# 27612      Hamburg Masters    Clay             M   2008-05-11       39.0
# 42591        Miami Masters    Hard             M   2013-03-20       64.0
# 31445   Cincinnati Masters    Hard             M   2009-08-16       42.0
# 49287  Monte Carlo Masters    Clay             M   2015-04-12       55.0
# 42750              US Open    Hard             G   2013-08-26       97.0
# 38503         Rome Masters    Clay             M   2012-05-13       55.0
# 10867              Estoril    Clay             A   2003-04-07       25.0
#
#              winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 45766     Lleyton Hewitt           R        180        AUS          33
# 17207  Nikolay Davydenko           R        178        RUS          24
# 41895       David Ferrer           R        175        ESP          31
# 27612        Andy Murray           R        190        GBR          21
# 42591        Andy Murray           R        190        GBR          26
# 31445     Lleyton Hewitt           R        180        AUS          28
# 49287     Novak Djokovic           R        188        SRB          28
# 42750     Novak Djokovic           R        188        SRB          26
# 38503       Rafael Nadal           L        185        ESP          26
# 10867      Tommy Robredo           R        180        ESP          21
#
#        winner_rank  winner_rank_points               score  best_of round  \
# 45766           38                1045             6-3 6-1      3.0   R32
# 17207            7                2045          7-6(3) 6-3      3.0   R16
# 41895            4                7220  6-3 3-6 7-6(4) 7-5      5.0   R64
# 27612           14                1410             6-3 6-3      3.0   R32
# 42591            3                8350             6-3 6-1      3.0   R64
# 31445           42                1105         6-1 2-6 6-3      3.0   R16
# 49287            1               13205         7-5 4-6 6-3      3.0     F
# 42750            1               10980         6-0 6-2 6-2      5.0   R32
# 38503            3                9105             7-5 6-3      3.0     F
# 10867           25                1190             6-2 6-3      3.0    QF
#
#        minutes  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  \
# 45766     65.0    0.0   3.0    46.0     27.0      21.0       8.0      8.0
# 17207     91.0    2.0   2.0    70.0     50.0      36.0      11.0     11.0
# 41895    179.0    6.0   4.0   131.0     84.0      64.0      22.0     21.0
# 27612     77.0    0.0   1.0    53.0     24.0      20.0      16.0      9.0
# 42591     57.0    8.0   2.0    50.0     35.0      28.0       9.0      8.0
# 31445     87.0    3.0   4.0    61.0     35.0      28.0      14.0     12.0
# 49287    163.0    2.0   5.0   102.0     60.0      40.0      21.0     16.0
# 42750    100.0    3.0   2.0    56.0     38.0      30.0      12.0     11.0
# 38503    141.0    0.0   0.0    69.0     39.0      27.0      17.0     10.0
# 10867     65.0    2.0   2.0    44.0     29.0      21.0      10.0      8.0
#
#        w_bpSaved  w_bpFaced
# 45766        0.0        1.0
# 17207        1.0        3.0
# 41895        3.0        7.0
# 27612        3.0        4.0
# 42591        3.0        3.0
# 31445        1.0        4.0
# 49287        6.0       10.0
# 42750        1.0        2.0
# 38503        6.0        7.0
# 10867        0.0        1.0

# %%
L = df[df['winner_hand'] == 'L']['winner_name'].tolist()#saves all leftees in a list
R = df[df['winner_hand'] == 'R']['winner_name'].tolist()

#creating dataframe for by combining both hands
dfnew = pd.concat([pd.DataFrame(L, columns=['Left']), pd.DataFrame(R, columns=['Right'])], axis=1)

#getting unique number of left and right
l = dfnew.Left.unique()
r = dfnew.Right.unique()

#new dataframe from both uniques
dfneww = pd.concat([pd.DataFrame(l, columns=['Left']), pd.DataFrame(r, columns=['Right'])], axis=1)

# %% [markdown]
# #### total number of left hands

# %%
tl = 0
for i in dfneww.Left:
    if i is 'Nan':
        pass
    else:
        tl = tl+1
print('TOTAL NUMBER OF LEFT HANDED WINNERS: ', tl)
# Out:
# TOTAL NUMBER OF LEFT HANDED WINNERS:  540

# %% [markdown]
# #### total number of right hands

# %%
rl = 0
for i in dfneww.Right:
    if i is 'Nan':
        pass
    else:
        tl = tl+1
print('TOTAL NUMBER OF RIGHT HAANDED WINNERS: ', tl)
# Out:
# TOTAL NUMBER OF RIGHT HAANDED WINNERS:  1080

# %% [markdown]
# #### hand of top ten winners

# %%
h = top.groupby('winner_hand')['winner_name'].unique()
print(h, '\n')
hh = top.groupby('winner_name')['winner_hand'].unique()
print(hh)
# Out:
# winner_hand
# L                                       [Rafael Nadal]
# R    [Roger Federer, Lleyton Hewitt, Andy Roddick, ...
# Name: winner_name, dtype: object
#
# winner_name
# Andy Murray          [R]
# Categories (1, object): [R]
# Andy Roddick         [R]
# Categories (1, object): [R]
# David Ferrer         [R]
# Categories (1, object): [R]
# Lleyton Hewitt       [R]
# Categories (1, object): [R]
# Nikolay Davydenko    [R]
# Categories (1, object): [R]
# Novak Djokovic       [R]
# Categories (1, object): [R]
# Rafael Nadal         [L]
# Categories (1, object): [L]
# Roger Federer        [R]
# Categories (1, object): [R]
# Tomas Berdych        [R]
# Categories (1, object): [R]
# Tommy Robredo        [R]
# Categories (1, object): [R]
# Name: winner_hand, dtype: object

# %%
rcParams['figure.figsize'] = 10, 7
default_color = sns.color_palette()[0]
ut = sns.countplot(data = top, x = 'winner_hand', color=default_color)

plt.xlabel('Hand')
plt.title('Hand of the top ten', fontsize=14, y=1.015)

plt.show()

# %%
sur = top.groupby('surface')['w_ace'].mean()
sur.plot(kind='bar', title='Surface with the most aces');

# %%
plt.figure(figsize=[10, 7])
bins = np.arange(0, df['minutes'].max()+1, 1)
plt.hist(data = df, x = 'minutes', bins=bins);
plt.title('Duration in Minutes(linear scaled)', fontsize=14, y=1.015)
plt.xlabel('minutes', labelpad=6, fontsize=12)
plt.ylabel('tourneys', labelpad=6, fontsize=12)
plt.show()

# %% [markdown]
# ## Bivariate analysis

# %%
rcParams['figure.figsize']= 10, 8
sns.countplot(data=top, x=top['winner_name'], hue= 'surface');
plt.xticks(rotation='vertical');

# %%
dfneww
# Out:
#                Left                      Right
# 0     Jan Siemerink              Antony Dupuis
# 1    Gianluca Pozzi          Fernando Gonzalez
# 2      Jeff Tarango        Paradorn Srichaphan
# 3     Stephane Huet          Jason Stoltenberg
# 4     Stefan Koubek                 Jiri Vanek
# ..              ...                        ...
# 535             NaN                    Ti Chen
# 536             NaN  Kittipong Wachiramanowong
# 537             NaN           Frederik Nielsen
# 538             NaN          Laurynas Grigelis
# 539             NaN                Pedro Sousa
#
# [540 rows x 2 columns]

# %%
# Out:
# TOTAL NUMBER OF LEFT HANDED WINNERS:  540

# %%
# Out:
# TOTAL NUMBER OF RIGHT HAANDED WINNERS:  1080
